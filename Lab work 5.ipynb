# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Get the data and display it

# %%
polls = pd.read_csv('Sales_Tax_Collections_by_State.csv')

# %%
polls.head()
# Out:
#       state      month  year    tax type       value  fips state  \
# 0  Delaware       July  2023  motor fuel         NaN          10
# 1     Idaho    January  2021  motor fuel  22273106.0          16
# 2   Alabama     August  2023  motor fuel  81898874.0           1
# 3     Maine   February  2021  motor fuel  16310504.0          23
# 4   Alabama  September  2023  motor fuel  85792362.0           1
#
#    numeric month  note         id
# 0              7   NaN  10_2023_7
# 1              1   NaN  16_2021_1
# 2              8   NaN   1_2023_8
# 3              2   NaN  23_2021_2
# 4              9   NaN   1_2023_9

# %%
polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2754 entries, 0 to 2753
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          2754 non-null   object
#  1   month          2754 non-null   object
#  2   year           2754 non-null   int64
#  3   tax type       2754 non-null   object
#  4   value          2273 non-null   float64
#  5   fips state     2754 non-null   int64
#  6   numeric month  2754 non-null   int64
#  7   note           0 non-null      float64
#  8   id             2754 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 193.8+ KB

# %% [markdown]
# ## Clean data

# %%
polls.apply(pd.unique)
# Out:
# state            [Delaware, Idaho, Alabama, Maine, Nebraska, Al...
# month            [July, January, August, February, September, M...
# year                                [2023, 2021, 2019, 2020, 2022]
# tax type                                              [motor fuel]
# value            [nan, 22273106.0, 81898874.0, 16310504.0, 8579...
# fips state       [10, 16, 1, 23, 31, 2, 4, 5, 6, 8, 9, 11, 12, ...
# numeric month              [7, 1, 8, 2, 9, 5, 10, 4, 12, 6, 3, 11]
# note                                                         [nan]
# id               [10_2023_7, 16_2021_1, 1_2023_8, 23_2021_2, 1_...
# dtype: object

# %%
polls.drop('note', axis=1,inplace=True)

# %%
polls.dropna(inplace=True)

# %%
polls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2273 entries, 1 to 2749
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          2273 non-null   object
#  1   month          2273 non-null   object
#  2   year           2273 non-null   int64
#  3   tax type       2273 non-null   object
#  4   value          2273 non-null   float64
#  5   fips state     2273 non-null   int64
#  6   numeric month  2273 non-null   int64
#  7   id             2273 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 159.8+ KB

# %% [markdown]
# ## 1. Additional variables: Percent - tax on fuel

# %% [markdown]
# ## Explain the potential impact: Base on percent, it can calculate how much people on their states contribute tax on fuel and balance with another state.

# %% [markdown]
# ## 2.Limitation

# %% [markdown]
# ### With this data, I want to improve quality of data so I follow on few steps below:
# - Data Cleaning:
#
# Identify and handle missing values appropriately.
# Remove duplicates and irrelevant data.
# Correct inaccuracies and inconsistencies in the data.
#
# - Outlier Detection:
#
# Analyze and address outliers that might skew our analysis.
# Use visualization techniques and statistical methods to identify outliers.
#
# - Data Profiling:
#
# Conduct data profiling to understand the distribution and characteristics of our data.
# Identify patterns and anomalies that may affect data quality.
#
# ### Like process, I clean up data, drop off Note columns and missing info in Value columns.

# %% [markdown]
# ## 3.Different data type
# #### The different data type help viewer understand and more comparable than normal.Like a raw data and a data has been sort, filter and visuallyzation, the second will be more attracted and show out the point of view of writer.
# ####  This approach offers a richer context, improved accuracy, and a holistic view of complex relationships. Combining different data types allows for the discovery of hidden patterns, better predictive modeling, and real-time insights, contributing to more informed decision-making. Additionally, it mitigates risks associated with relying on a single source and fosters innovation by uncovering new correlations and trends

# %% [markdown]
# ## 4.Exaimine data
#
# #### For historical data, we analyze trends and patterns over a longer time period, providing valuable context. Incorporating future data allows for predictive modeling and forecasting.
#
# #### Challenges with time series data include seasonality, trend identification, and handling missing values. To address these challenges, employ techniques such as seasonality decomposition, trend analysis, and imputation methods for missing data. Additionally, ensure consistency in time intervals and account for potential biases introduced by changes in data collection methods over time. Regularly updating models with new data helps maintain their relevance and accuracy.

# %% [markdown]
# ## 5.Geographical

# %% [markdown]
# ### Yes, including geographic information, such as location data or regional demographics, can significantly enhance the geographical scope of your analysis. Spatial analysis techniques can provide valuable insights into spatial patterns, relationships, and trends.
# ### Like Regional Demographic Profiling:
#
# ### Integrate regional demographic data to create profiles for different areas. This can help in understanding the socio-economic context and tailoring strategies accordingly.

# %% [markdown]
# ### 6.Are there external factors or events that you haven't considered in your analysis? How might you expand your analysis to account for external influences, such as economic trends, legislative changes, or global events?

# %% [markdown]
# ### Considering external factors and events is crucial for a comprehensive and robust analysis. Here are ways I might expand your analysis
#
# ### Economic Trends:
#
# ### Incorporate economic indicators relevant to your industry or market, such as GDP growth, inflation rates, or interest rates.
# ### Assess how changes in economic conditions might impact consumer purchasing behavior, disposable income, and overall market demand.

# %% [markdown]
# ### 7.Explore the possibility of expanding the analysis to different subpopulations or segments within the data. How might you break down your analysis by age groups, gender, or other demographic variables to uncover insights that are specific to each subgroup?

# %% [markdown]
# ### Breaking down the analysis by different subpopulations or segments within the data can provide valuable insights into variations across demographic groups. Here are ways you might break down your analysis by age groups, gender, or other demographic variables:
#
# ### Age Groups,gender, income levels,region or loyalty.

# %% [markdown]
# ### 8.Consider incorporating machine learning techniques or more advanced statistical methods to broaden the analytical techniques used in your project. How would these advanced methods help you gain deeper insights and make more accurate predictions?

# %% [markdown]
# ### Here are ways these advanced methods can benefit your project:
#
# #### Predictive Modeling
# #### Segmentation and Clustering
# #### Feature Importance Analysis
# #### Time Series Analysis
# #### Recommendation Systems

# %% [markdown]
# ### 9.	Assess the ethical and privacy implications of expanding the scope of your analysis, especially when dealing with sensitive or personal data. How can you ensure that your expanded analysis is conducted responsibly and in compliance with relevant regulations?

# %% [markdown]
# ### Expanding the scope of the analysis, especially when dealing with sensitive or personal data, requires careful consideration of ethical and privacy implications. Here are steps to ensure responsible conduct and compliance with relevant regulations:
# #### Privacy
# #### Informed Consent
# #### Anonymization and Aggregation
# #### Security measure
# #### Transparency

# %% [markdown]
# ### 10.	In terms of communication and visualization, how might you expand the way you present your analysis results to different audiences, such as executives, technical experts, or the general public?

# %% [markdown]
# ### Expanding the way you present analysis results to different audiences involves tailoring your communication and visualization methods to meet the needs and preferences of each audience.
# #### Technical Experts:
# ##### Detailed Technical Reports
# ##### Code Repositories
# ##### Advanced Visualizations
# ##### Interactive Model Demonstrations
#
# #### General Public:
# ##### Infographics and Visual Storytelling
# ##### Plain Language Descriptions
# ##### Social Media Summaries
